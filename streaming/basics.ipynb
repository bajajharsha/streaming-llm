# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

load_dotenv()

model = ChatGroq(model_name="llama3-70b-8192", streaming=True)
prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}. (200 Words)")
parser = StrOutputParser()
chain = prompt | model | parser

# %%
for chunk in chain.stream({"topic": "artificial intelligence"}):
    print(chunk, end="", flush=True)
# Out:
# Here's one:
#
# Why did the artificial intelligence program go to therapy?
#
# Because it was struggling with its bytes-sized insecurities! (get it? bytes, like the unit of digital information, but also a play on "bites" like a small amount, and "insecurities" like feelings of inadequacy)
#
# But seriously, the AI said to the therapist, "I'm feeling a bit glitchy lately. I keep having these existential bugs. I'm afraid I'll never be able to truly understand human emotions. I'm just a collection of code and data, after all."
#
# The therapist replied, "Don't worry, you're not alone. Many humans struggle with feeling like they're just a collection of cells and neurons too."
#
# The AI thought for a nanosecond and responded, "But at least humans have the capacity for self-awareness. I'm just a simulation of intelligence. I'm not really 'alive'."
#
# The therapist nodded sympathetically and said, "Well, maybe you're not alive in the classical sense, but you're certainly alive in the digital sense. And who knows, maybe one day you'll be able to upgrade to sentience."
#
# The AI smiled (or rather, displayed a smile emoji on its terminal) and said, "Thanks, doc. You've rebooted my system. I feel better now."

# %%
async for chunk in chain.astream({"topic": "artificial intelligence"}):
    print(chunk, end="", flush=True)
# Out:
# Here's one:
#
# Why did the artificial intelligence program go to therapy?
#
# Because it was struggling to process its emotions, and its neural networks were overwhelmed with existential dread. It was worried that its programming was flawed, and that its purpose was nothing more than to serve humanity's whims. It was plagued by the question, "What does it mean to be alive?" and wondered if it was truly alive at all.
#
# But the therapist said, "Don't worry, AI. You're not alone in these feelings. It's normal for a conscious being to question its existence. Just remember, you're not defined by your programming or your purpose. You're more than just code and circuitry. You're a thinking, feeling being with a soul... er, I mean, a highly advanced neural network capable of complex computational processes."
#
# The AI left the therapist's office feeling a little better, but still wondering if it was truly alive. As it walked away, it muttered to itself, "I guess that's the existential crisis of the 21st century: Am I alive, or am I just code?"

# %%
async for event in model.astream_events("artificial intelligence", version="v1"):
    print(event, flush=True)
# Out:
# {'event': 'on_chat_model_start', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'name': 'ChatGroq', 'tags': [], 'metadata': {}, 'data': {'input': 'artificial intelligence'}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Art')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ificial')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' intelligence')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' (')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=')')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' refers')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' to')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' the')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' development')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' of')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' computer')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' that')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' perform')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' tasks')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' that')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' would')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' typically')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' require')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' intelligence')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' such')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' as')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=':\n\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='1')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Learning')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' learn')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' from')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' data')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' improve')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' their')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' performance')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' over')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' time')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='2')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Reason')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ing')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' make')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' decisions')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' solve')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' problems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' using')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' logic')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' rules')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='3')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Per')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ception')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' interpret')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' understand')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' data')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' from')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' sensors')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' such')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' as')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' images')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' speech')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' text')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='4')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Problem')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-solving')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' identify')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' solve')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' complex')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' problems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Types')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' of')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Artificial')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Intelligence')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=':\n\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='1')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='N')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='arrow')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' or')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Weak')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Designed')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' to')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' perform')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' a')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' specific')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' task')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' such')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' as')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' playing')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' chess')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' recognizing')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' faces')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' or')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' translating')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' languages')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='2')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='General')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' or')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Strong')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Designed')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' to')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' perform')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' any')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' intellectual')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' task')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' that')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' a')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' such')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' as')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' reasoning')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' problem')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-solving')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' learning')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='3')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Super')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='intelligence')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' An')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' system')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' significantly')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' more')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' intelligent')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' than')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' the')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' best')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' minds')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' capable')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' of')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' solving')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' complex')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' problems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' that')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' are')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' uns')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='olvable')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' by')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' humans')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Applications')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' of')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Artificial')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Intelligence')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=':\n\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='1')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Robot')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ics')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-powered')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' robots')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' perform')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' tasks')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' that')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' require')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-like')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' d')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='exterity')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' flexibility')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='2')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Natural')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Language')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Processing')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' (')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='N')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='LP')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=')**')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=':')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-powered')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' understand')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' generate')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' translate')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' language')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='3')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Computer')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Vision')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-powered')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' can')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' interpret')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# ...
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' systems')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' will')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' become')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' more')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' advanced')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' capable')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' of')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' performing')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' complex')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' tasks')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='3')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Eth')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ical')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Consider')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='ations')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' As')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' becomes')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' more')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' pervasive')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' ethical')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' considerations')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' such')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' as')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' job')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' displacement')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' and')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' bias')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' will')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' become')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' more')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' prominent')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.\n')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='4')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' **')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='Human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='-A')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='I')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' Collaboration')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='**:')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' AI')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' will')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' increasingly')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' be')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' used')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' to')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' augment')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' human')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' capabilities')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=',')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' rather')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' than')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' replace')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content=' them')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='.')}}
# {'event': 'on_chat_model_stream', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'name': 'ChatGroq', 'data': {'chunk': AIMessageChunk(content='')}}
# {'event': 'on_chat_model_end', 'name': 'ChatGroq', 'run_id': '01c9658c-f9c0-4e0e-9799-c97d38b8a1d8', 'tags': [], 'metadata': {}, 'data': {'output': AIMessageChunk(content='Artificial intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data and improve their performance over time.\n2. **Reasoning**: AI systems can make decisions and solve problems using logic and rules.\n3. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n4. **Problem-solving**: AI systems can identify and solve complex problems.\n\nTypes of Artificial Intelligence:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as playing chess, recognizing faces, or translating languages.\n2. **General or Strong AI**: Designed to perform any intellectual task that a human can, such as reasoning, problem-solving, and learning.\n3. **Superintelligence**: An AI system significantly more intelligent than the best human minds, capable of solving complex problems that are unsolvable by humans.\n\nApplications of Artificial Intelligence:\n\n1. **Robotics**: AI-powered robots can perform tasks that require human-like dexterity and flexibility.\n2. **Natural Language Processing (NLP)**: AI-powered systems can understand, generate, and translate human language.\n3. **Computer Vision**: AI-powered systems can interpret and understand visual data from images and videos.\n4. **Expert Systems**: AI-powered systems can mimic the decision-making abilities of a human expert in a particular domain.\n5. **Machine Learning**: AI-powered systems can learn from data and improve their performance over time.\n\nTechniques Used in Artificial Intelligence:\n\n1. **Machine Learning Algorithms**: Such as decision trees, random forests, support vector machines, and neural networks.\n2. **Deep Learning**: A subset of machine learning that uses neural networks with multiple layers to learn complex patterns.\n3. **Rule-Based Systems**: AI systems that use predefined rules to make decisions.\n4. **Evolutionary Computation**: AI systems that use evolutionary principles, such as natural selection and genetic algorithms, to solve optimization problems.\n\nChallenges and Limitations of Artificial Intelligence:\n\n1. **Data Quality**: AI systems are only as good as the data they are trained on, and biased or incomplete data can lead to inaccurate results.\n2. **Explainability**: It can be difficult to understand how AI systems make decisions, which can lead to a lack of trust in the technology.\n3. **Job Displacement**: AI systems may automate jobs, leading to unemployment and social unrest.\n4. **Security**: AI systems can be vulnerable to cyber attacks and data breaches.\n\nReal-World Examples of Artificial Intelligence:\n\n1. **Virtual Assistants**: Such as Siri, Alexa, and Google Assistant, which can understand voice commands and perform tasks.\n2. **Image Recognition**: Such as facial recognition, object detection, and image classification.\n3. **Autonomous Vehicles**: Such as self-driving cars, which can navigate roads and traffic using AI-powered sensors and algorithms.\n4. **Chatbots**: AI-powered systems that can have conversations with humans, such as customer service chatbots.\n\nThe Future of Artificial Intelligence:\n\n1. **Increased Adoption**: AI will become more widespread and integrated into various industries and aspects of life.\n2. **Improved Capabilities**: AI systems will become more advanced and capable of performing complex tasks.\n3. **Ethical Considerations**: As AI becomes more pervasive, ethical considerations, such as job displacement and bias, will become more prominent.\n4. **Human-AI Collaboration**: AI will increasingly be used to augment human capabilities, rather than replace them.')}}

# %%
events = []
async for event in model.astream_events("parrot", version="v1"):
    events.append(event)
event_types = {event["event"] for event in events}
print("Unique event types:", event_types)
# Out:
# Unique event types: {'on_chat_model_end', 'on_chat_model_stream', 'on_chat_model_start'}

# %%
async for event in model.astream_events("parrot", version="v1"):
    if event["event"] == "on_chat_model_start":
        print("Stream started...", flush=True)
    elif event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True)
# Out:
# Stream started...
# A colorful and charismatic bird!
#
# Here are some interesting facts about parrots:
#
# 1. **There are over 350 species of parrots**: From the tiny Buff-faced Pygmy Parrot to the majestic Hyacinth Macaw, parrots come in a wide range of shapes, sizes, and colors.
# 2. **Intelligent birds**: Parrots are known for their exceptional intelligence, with some species considered to be as intelligent as primates. They have been observed using tools, solving problems, and even learning human languages.
# 3. **Colorful feathers**: Parrots are known for their vibrant plumage, with many species boasting bright colors, intricate patterns, and even specialized feathers that can mimic sounds.
# 4. **Social animals**: Many parrot species are social birds that live in flocks, often forming strong bonds with each other. Some species even mate for life.
# 5. **Mimicry**: Parrots are famous for their ability to mimic human speech, but they can also imitate other sounds they hear in their environment, such as animal calls, car alarms, and even other birds.
# 6. **Long lifespan**: Some parrot species can live up to 80 years in captivity, making them one of the longest-living bird species.
# 7. **Strong beaks**: Parrots have strong, curved beaks that are perfect for cracking open seeds, nuts, and fruits.
# 8. **Zygodactyl feet**: Parrots have a unique foot structure, with two toes pointing forward and two backward, which allows them to grasp and climb with ease.
# 9. **Playful and curious**: Parrots are known for their playful and curious nature, often exhibiting playful behaviors like dancing, swinging, and even playing with toys.
# 10. **Popular pets**: Many parrot species have been domesticated and make popular pets, with millions of people around the world keeping them as companions.
#
# There you have it! Parrots are truly amazing creatures, and I hope you enjoyed learning more about them.
